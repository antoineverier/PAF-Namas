# %%
import torch
import torch.nn as nn
from torchvision.transforms import transforms
import numpy as np
from torch.autograd import Variable
from torchvision.models import squeezenet1_1
import torch.functional as F
from io import open
import os
from PIL import Image
import pathlib
import glob
#import cv2

train_path='ISIC_2018_TEST/train'


#categories
root=pathlib.Path(train_path)
classes=sorted([j.name.split('/')[-1] for j in root.iterdir()])

# %%
class ConvNet(nn.Module):
    def __init__(self,num_classes=2):
        super(ConvNet,self).__init__()
        
        #Output size after convolution filter
        #((w-f+2P)/s) +1
        
        #Input shape= (256,3,150,150)
        
        self.conv1=nn.Conv2d(in_channels=3,out_channels=12,kernel_size=3,stride=1,padding=1)
        #Shape= (256,12,150,150)
        self.bn1=nn.BatchNorm2d(num_features=12)
        #Shape= (256,12,150,150)
        self.relu1=nn.ReLU()
        #Shape= (256,12,150,150)
        
        self.pool=nn.MaxPool2d(kernel_size=2)
        #Reduce the image size be factor 2
        #Shape= (256,12,75,75)
        
        
        self.conv2=nn.Conv2d(in_channels=12,out_channels=20,kernel_size=3,stride=1,padding=1)
        #Shape= (256,20,75,75)
        self.relu2=nn.ReLU()
        #Shape= (256,20,75,75)
        
        
        
        self.conv3=nn.Conv2d(in_channels=20,out_channels=32,kernel_size=3,stride=1,padding=1)
        #Shape= (256,32,75,75)
        self.bn3=nn.BatchNorm2d(num_features=32)
        #Shape= (256,32,75,75)
        self.relu3=nn.ReLU()
        #Shape= (256,32,75,75)
        
        
        self.fc=nn.Linear(in_features=75 * 75 * 32,out_features=num_classes)
         #Feed forwad function
        
    def forward(self,input):
        output=self.conv1(input)
        output=self.bn1(output)
        output=self.relu1(output)
            
        output=self.pool(output)
            
        output=self.conv2(output)
        output=self.relu2(output)
            
        output=self.conv3(output)
        output=self.bn3(output)
        output=self.relu3(output)
            
            
            #Above output will be in matrix form, with shape (256,32,75,75)
            
        output=output.view(-1,32*75*75)
            
            
        output=self.fc(output)
            
        return output

# %%
checkpoint=torch.load('best_checkpoint.model')
model=ConvNet(num_classes=2)
model.load_state_dict(checkpoint)
model.eval()
# Out:
# ConvNet(
#   (conv1): Conv2d(3, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn1): BatchNorm2d(12, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv2d(12, 20, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (relu2): ReLU()
#   (conv3): Conv2d(20, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (bn3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu3): ReLU()
#   (fc): Linear(in_features=180000, out_features=2, bias=True)
# )

# %%
#Transforms
transformer=transforms.Compose([
    transforms.Resize((150,150)),
    transforms.ToTensor(),  #0-255 to 0-1, numpy to tensors
    transforms.Normalize([0.5,0.5,0.5], # 0-1 to [-1,1] , formula (x-mean)/std
                        [0.5,0.5,0.5])
])

# %%
#prediction function
def prediction(img_path,transformer):
    
    image=Image.open(img_path)
    
    image_tensor=transformer(image).float()
    
    
    image_tensor=image_tensor.unsqueeze_(0)
    
    if torch.cuda.is_available():
        image_tensor.cuda()
        
    input=Variable(image_tensor)
    
    
    output=model(input)
    
    index=output.data.numpy().argmax()
    
    pred=classes[index]
    
    return pred

pred_path='archive'
images_path=glob.glob(pred_path+'/*.jpg')
pred_dict={}

for i in images_path:
    pred_dict[i[i.rfind('/')+1:]]=prediction(i,transformer)
pred_dict
# Out:
# {'archive\\ISIC_0012169.JPG': 'Benign',
#  'archive\\ISIC_0012236.JPG': 'Benign',
#  'archive\\ISIC_0012292.JPG': 'Benign',
#  'archive\\ISIC_0012302.JPG': 'Benign',
#  'archive\\ISIC_0012337.JPG': 'Benign',
#  'archive\\ISIC_0012373.JPG': 'Benign',
#  'archive\\ISIC_0012405.JPG': 'Benign',
#  'archive\\ISIC_0012418.JPG': 'Benign',
#  'archive\\ISIC_0012456.JPG': 'Benign',
#  'archive\\ISIC_0012472.JPG': 'Malignant',
#  'archive\\ISIC_0012479.JPG': 'Benign',
#  'archive\\ISIC_0012558.JPG': 'Benign',
#  'archive\\ISIC_0012559.JPG': 'Benign',
#  'archive\\ISIC_0012560.JPG': 'Malignant',
#  'archive\\ISIC_0012563.JPG': 'Benign',
#  'archive\\ISIC_0012564.JPG': 'Benign',
#  'archive\\ISIC_0012566.JPG': 'Malignant',
#  'archive\\ISIC_0012572.JPG': 'Benign',
#  'archive\\ISIC_0012591.JPG': 'Benign',
#  'archive\\ISIC_0012592.JPG': 'Benign',
#  'archive\\ISIC_0012596.JPG': 'Benign',
#  'archive\\ISIC_0012599.JPG': 'Malignant',
#  'archive\\ISIC_0012603.JPG': 'Benign',
#  'archive\\ISIC_0012606.JPG': 'Benign',
#  'archive\\ISIC_0012607.JPG': 'Benign',
#  'archive\\ISIC_0012611.JPG': 'Benign',
#  'archive\\ISIC_0012624.JPG': 'Benign',
#  'archive\\ISIC_0012625.JPG': 'Benign',
#  'archive\\ISIC_0012634.JPG': 'Benign',
#  'archive\\ISIC_0012647.JPG': 'Benign',
#  'archive\\ISIC_0012650.JPG': 'Benign',
#  'archive\\ISIC_0012651.JPG': 'Benign',
#  'archive\\ISIC_0012698.JPG': 'Benign',
#  'archive\\ISIC_0012925.JPG': 'Benign',
#  'archive\\ISIC_0012935.JPG': 'Benign',
#  'archive\\ISIC_0012948.JPG': 'Benign',
#  'archive\\ISIC_0013143.JPG': 'Benign',
#  'archive\\ISIC_0014676.JPG': 'Benign',
#  'archive\\ISIC_0014758.JPG': 'Benign',
#  'archive\\ISIC_0014759.JPG': 'Benign',
#  'archive\\ISIC_0014887.JPG': 'Benign',
#  'archive\\ISIC_0014888.JPG': 'Benign',
#  'archive\\ISIC_0014905.JPG': 'Benign',
#  'archive\\ISIC_0014906.JPG': 'Benign',
#  'archive\\ISIC_0014953.JPG': 'Benign',
#  'archive\\ISIC_0014967.JPG': 'Benign',
#  'archive\\ISIC_0014976.JPG': 'Benign',
#  'archive\\ISIC_0014997.JPG': 'Benign',
#  'archive\\ISIC_0015001.JPG': 'Benign',
#  'archive\\ISIC_0015029.JPG': 'Benign',
#  'archive\\ISIC_0015069.JPG': 'Benign',
#  'archive\\ISIC_0015074.JPG': 'Benign',
#  'archive\\ISIC_0015085.JPG': 'Benign',
#  'archive\\ISIC_0015088.JPG': 'Benign',
#  'archive\\ISIC_0015092.JPG': 'Benign',
#  'archive\\ISIC_0015094.JPG': 'Benign',
#  'archive\\ISIC_0015104.JPG': 'Malignant',
#  'archive\\ISIC_0015117.JPG': 'Benign',
#  'archive\\ISIC_0015120.JPG': 'Benign',
#  'archive\\ISIC_0015121.JPG': 'Benign',
#  'archive\\ISIC_0015137.JPG': 'Benign',
#  'archive\\ISIC_0015154.JPG': 'Benign',
#  'archive\\ISIC_0015165.JPG': 'Benign',
#  'archive\\ISIC_0015169.JPG': 'Benign',
#  'archive\\ISIC_0015227.JPG': 'Benign',
#  'archive\\ISIC_0015228.JPG': 'Benign',
#  'archive\\ISIC_0015257.JPG': 'Benign',
#  'archive\\ISIC_0015261.JPG': 'Benign',
#  'archive\\ISIC_0015265.JPG': 'Benign',
#  'archive\\ISIC_0015275.JPG': 'Benign',
#  'archive\\ISIC_0015281.JPG': 'Benign',
#  'archive\\ISIC_0015290.JPG': 'Benign',
#  'archive\\ISIC_0015338.JPG': 'Benign',
#  'archive\\ISIC_0015350.JPG': 'Benign',
#  'archive\\ISIC_0015352.JPG': 'Benign',
#  'archive\\ISIC_0015365.JPG': 'Benign',
#  'archive\\ISIC_0015366.JPG': 'Benign',
#  'archive\\ISIC_0015375.JPG': 'Malignant',
#  'archive\\ISIC_0015380.JPG': 'Benign',
#  'archive\\ISIC_0015381.JPG': 'Benign',
#  'archive\\ISIC_0015385.JPG': 'Benign',
#  'archive\\ISIC_0015389.JPG': 'Benign',
#  'archive\\ISIC_0015398.JPG': 'Benign',
#  'archive\\ISIC_0015399.JPG': 'Benign',
#  'archive\\ISIC_0015408.JPG': 'Benign',
#  'archive\\ISIC_0015430.JPG': 'Benign',
#  'archive\\ISIC_0015435.JPG': 'Benign',
#  'archive\\ISIC_0015438.JPG': 'Benign',
#  'archive\\ISIC_0015441.JPG': 'Benign',
#  'archive\\ISIC_0015448.JPG': 'Malignant',
#  'archive\\ISIC_0015450.JPG': 'Benign',
#  'archive\\ISIC_0015451.JPG': 'Benign',
#  'archive\\ISIC_0015463.JPG': 'Malignant',
#  'archive\\ISIC_0015469.JPG': 'Benign',
#  'archive\\ISIC_0015470.JPG': 'Benign',
#  'archive\\ISIC_0015473.JPG': 'Benign',
#  'archive\\ISIC_0015478.JPG': 'Benign',
#  'archive\\ISIC_0015479.JPG': 'Malignant',
#  'archive\\ISIC_0015486.JPG': 'Benign',
#  'archive\\ISIC_0015501.JPG': 'Benign',
#  'archive\\ISIC_0015502.JPG': 'Benign',
#  'archive\\ISIC_0015504.JPG': 'Benign',
#  'archive\\ISIC_0015507.JPG': 'Benign',
#  'archive\\ISIC_0015520.JPG': 'Benign',
#  'archive\\ISIC_0015521.JPG': 'Benign',
#  'archive\\ISIC_0015524.JPG': 'Benign',
#  'archive\\ISIC_0015525.JPG': 'Benign',
#  'archive\\ISIC_0015551.JPG': 'Benign',
#  'archive\\ISIC_0015558.JPG': 'Benign',
#  'archive\\ISIC_0015569.JPG': 'Malignant',
#  'archive\\ISIC_0015570.JPG': 'Benign',
#  'archive\\ISIC_0015578.JPG': 'Benign',
#  'archive\\ISIC_0015583.JPG': 'Benign',
#  'archive\\ISIC_0015587.JPG': 'Benign',
#  'archive\\ISIC_0015596.JPG': 'Benign',
#  'archive\\ISIC_0015602.JPG': 'Benign',
#  'archive\\ISIC_0015606.JPG': 'Benign',
#  'archive\\ISIC_0015613.JPG': 'Benign',
#  'archive\\ISIC_0015621.JPG': 'Benign',
#  'archive\\ISIC_0015629.JPG': 'Benign',
#  'archive\\ISIC_0015633.JPG': 'Benign',
#  'archive\\ISIC_0015635.JPG': 'Benign',
#  'archive\\ISIC_0015637.JPG': 'Benign',
#  'archive\\ISIC_0015642.JPG': 'Benign',
#  'archive\\ISIC_0015970.JPG': 'Benign',
#  'archive\\ISIC_0015977.JPG': 'Benign',
#  'archive\\ISIC_0016010.JPG': 'Benign',
#  'archive\\ISIC_0016020.JPG': 'Benign',
#  'archive\\ISIC_0016021.JPG': 'Benign',
#  'archive\\ISIC_0016039.JPG': 'Benign',
#  'archive\\ISIC_0016047.JPG': 'Malignant',
#  'archive\\ISIC_0016067.JPG': 'Benign',
#  'archive\\ISIC_0016186.JPG': 'Benign',
#  'archive\\ISIC_0016197.JPG': 'Benign',
#  'archive\\ISIC_0016199.JPG': 'Benign',
#  'archive\\ISIC_0016211.JPG': 'Benign',
#  'archive\\ISIC_0016274.JPG': 'Benign',
#  'archive\\ISIC_0016318.JPG': 'Benign',
#  'archive\\ISIC_0016344.JPG': 'Malignant',
#  'archive\\ISIC_0016363.JPG': 'Benign',
#  'archive\\ISIC_0016364.JPG': 'Benign',
#  'archive\\ISIC_0016438.JPG': 'Benign',
#  'archive\\ISIC_0016524.JPG': 'Benign',
#  'archive\\ISIC_0016575.JPG': 'Benign',
#  'archive\\ISIC_0016663.JPG': 'Benign',
#  'archive\\ISIC_0016716.JPG': 'Benign',
#  'archive\\ISIC_0016726.JPG': 'Malignant',
#  'archive\\ISIC_0016736.JPG': 'Benign',
#  'archive\\ISIC_0016837.JPG': 'Benign',
#  'archive\\ISIC_0016844.JPG': 'Benign',
#  'archive\\ISIC_0016911.JPG': 'Benign',
#  'archive\\ISIC_0016963.JPG': 'Benign',
#  'archive\\ISIC_0017026.JPG': 'Malignant',
#  'archive\\ISIC_0017036.JPG': 'Benign',
#  'archive\\ISIC_0017069.JPG': 'Benign',
#  'archive\\ISIC_0017073.JPG': 'Benign',
#  'archive\\ISIC_0017201.JPG': 'Benign',
#  'archive\\ISIC_0017259.JPG': 'Benign',
#  'archive\\ISIC_0017264.JPG': 'Benign',
#  'archive\\ISIC_0017268.JPG': 'Benign',
#  'archive\\ISIC_0017289.JPG': 'Benign',
#  'archive\\ISIC_0017292.JPG': 'Benign',
#  'archive\\ISIC_0017348.JPG': 'Benign',
#  'archive\\ISIC_0017350.JPG': 'Malignant',
#  'archive\\ISIC_0017355.JPG': 'Benign',
#  'archive\\ISIC_0017385.JPG': 'Benign',
#  'archive\\ISIC_0017389.JPG': 'Benign',
#  'archive\\ISIC_0017392.JPG': 'Benign',
#  'archive\\ISIC_0017406.JPG': 'Benign',
#  'archive\\ISIC_0017409.JPG': 'Benign',
#  'archive\\ISIC_0017411.JPG': 'Benign',
#  'archive\\ISIC_0017412.JPG': 'Benign',
#  'archive\\ISIC_0017413.JPG': 'Benign',
#  'archive\\ISIC_0017414.JPG': 'Benign',
#  'archive\\ISIC_0017415.JPG': 'Benign',
#  'archive\\ISIC_0017422.JPG': 'Malignant',
#  'archive\\ISIC_0017427.JPG': 'Benign',
#  'archive\\ISIC_0017428.JPG': 'Benign',
#  'archive\\ISIC_0017431.JPG': 'Benign',
#  'archive\\ISIC_0017432.JPG': 'Benign',
#  'archive\\ISIC_0017433.JPG': 'Benign',
#  'archive\\ISIC_0017434.JPG': 'Benign',
#  'archive\\ISIC_0017436.JPG': 'Benign',
#  'archive\\ISIC_0017443.JPG': 'Benign',
#  'archive\\ISIC_0017444.JPG': 'Benign',
#  'archive\\ISIC_0017448.JPG': 'Benign',
#  'archive\\ISIC_0017449.JPG': 'Benign',
#  'archive\\ISIC_0017451.JPG': 'Benign',
#  'archive\\ISIC_0017453.JPG': 'Benign',
#  'archive\\ISIC_0017455.JPG': 'Benign',
#  'archive\\ISIC_0017464.JPG': 'Benign',
#  'archive\\ISIC_0017465.JPG': 'Benign',
#  'archive\\ISIC_0017469.JPG': 'Benign',
#  'archive\\ISIC_0017479.JPG': 'Benign',
#  'archive\\ISIC_0017483.JPG': 'Benign',
#  'archive\\ISIC_0017485.JPG': 'Benign',
#  'archive\\ISIC_0017486.JPG': 'Malignant',
#  'archive\\ISIC_0017675.JPG': 'Benign',
#  'archive\\ISIC_0017689.JPG': 'Benign',
#  'archive\\ISIC_0017693.JPG': 'Benign',
#  'archive\\ISIC_0017704.JPG': 'Benign',
#  'archive\\ISIC_0017750.JPG': 'Benign',
#  'archive\\ISIC_0017775.JPG': 'Benign',
#  'archive\\ISIC_0017789.JPG': 'Benign',
#  'archive\\ISIC_0017793.JPG': 'Benign',
#  'archive\\ISIC_0017856.JPG': 'Benign',
#  'archive\\ISIC_0017883.JPG': 'Benign',
#  'archive\\ISIC_0017891.JPG': 'Benign',
#  'archive\\ISIC_0017919.JPG': 'Malignant',
#  'archive\\ISIC_0017939.JPG': 'Malignant',
#  'archive\\ISIC_0017951.JPG': 'Benign',
#  'archive\\ISIC_0017970.JPG': 'Benign',
#  'archive\\ISIC_0017973.JPG': 'Benign',
#  'archive\\ISIC_0017987.JPG': 'Benign',
#  'archive\\ISIC_0017990.JPG': 'Benign',
#  'archive\\ISIC_0017993.JPG': 'Benign',
#  'archive\\ISIC_0018039.JPG': 'Benign',
#  'archive\\ISIC_0018040.JPG': 'Benign',
#  'archive\\ISIC_0018048.JPG': 'Benign',
#  'archive\\ISIC_0018058.JPG': 'Benign',
#  'archive\\ISIC_0018088.JPG': 'Benign',
#  'archive\\ISIC_0018090.JPG': 'Malignant',
#  'archive\\ISIC_0018108.JPG': 'Malignant',
#  'archive\\ISIC_0018109.JPG': 'Benign',
#  'archive\\ISIC_0018126.JPG': 'Malignant',
#  'archive\\ISIC_0018172.JPG': 'Benign',
#  'archive\\ISIC_0018184.JPG': 'Benign',
#  'archive\\ISIC_0018185.JPG': 'Benign',
#  'archive\\ISIC_0018200.JPG': 'Benign',
#  'archive\\ISIC_0018209.JPG': 'Benign',
#  'archive\\ISIC_0018278.JPG': 'Benign',
#  'archive\\ISIC_0018286.JPG': 'Benign',
#  'archive\\ISIC_0018290.JPG': 'Benign',
#  'archive\\ISIC_0018297.JPG': 'Benign',
#  'archive\\ISIC_0018324.JPG': 'Malignant',
#  'archive\\ISIC_0018325.JPG': 'Malignant',
#  'archive\\ISIC_0018336.JPG': 'Benign',
#  'archive\\ISIC_0018339.JPG': 'Benign',
#  'archive\\ISIC_0018345.JPG': 'Benign',
#  'archive\\ISIC_0018371.JPG': 'Benign',
#  'archive\\ISIC_0018377.JPG': 'Benign',
#  'archive\\ISIC_0018392.JPG': 'Benign',
#  'archive\\ISIC_0018405.JPG': 'Benign',
#  'archive\\ISIC_0018413.JPG': 'Benign',
#  'archive\\ISIC_0018415.JPG': 'Benign',
#  'archive\\ISIC_0018424.JPG': 'Benign',
#  'archive\\ISIC_0018436.JPG': 'Benign',
#  'archive\\ISIC_0018484.JPG': 'Benign',
#  'archive\\ISIC_0018507.JPG': 'Benign',
#  'archive\\ISIC_0018527.JPG': 'Benign',
#  'archive\\ISIC_0018535.JPG': 'Malignant',
#  'archive\\ISIC_0018573.JPG': 'Benign',
#  'archive\\ISIC_0018580.JPG': 'Benign',
#  'archive\\ISIC_0018593.JPG': 'Benign',
#  'archive\\ISIC_0018602.JPG': 'Benign',
#  'archive\\ISIC_0018603.JPG': 'Benign',
#  'archive\\ISIC_0018627.JPG': 'Malignant',
#  'archive\\ISIC_0018633.JPG': 'Malignant',
#  'archive\\ISIC_0018662.JPG': 'Benign',
#  'archive\\ISIC_0018677.JPG': 'Benign',
#  'archive\\ISIC_0018711.JPG': 'Benign',
#  'archive\\ISIC_0018727.JPG': 'Benign',
#  'archive\\ISIC_0018730.JPG': 'Benign',
#  'archive\\ISIC_0018734.JPG': 'Benign',
#  'archive\\ISIC_0018738.JPG': 'Benign',
#  'archive\\ISIC_0018744.JPG': 'Benign',
#  'archive\\ISIC_0018747.JPG': 'Benign',
#  'archive\\ISIC_0018766.JPG': 'Benign',
#  'archive\\ISIC_0018774.JPG': 'Benign',
#  'archive\\ISIC_0018799.JPG': 'Benign',
#  'archive\\ISIC_0018819.JPG': 'Malignant',
#  'archive\\ISIC_0018889.JPG': 'Benign',
#  'archive\\ISIC_0018917.JPG': 'Malignant',
#  'archive\\ISIC_0018929.JPG': 'Malignant',
#  'archive\\ISIC_0018941.JPG': 'Benign',
#  'archive\\ISIC_0018949.JPG': 'Benign',
#  'archive\\ISIC_0018960.JPG': 'Benign',
#  'archive\\ISIC_0018964.JPG': 'Benign',
#  'archive\\ISIC_0018989.JPG': 'Benign',
#  'archive\\ISIC_0019016.JPG': 'Benign',
#  'archive\\ISIC_0019030.JPG': 'Benign',
#  'archive\\ISIC_0019062.JPG': 'Benign',
#  'archive\\ISIC_0019067.JPG': 'Benign',
#  'archive\\ISIC_0019088.JPG': 'Benign',
#  'archive\\ISIC_0019090.JPG': 'Benign',
#  'archive\\ISIC_0019092.JPG': 'Benign',
#  'archive\\ISIC_0019114.JPG': 'Benign',
#  'archive\\ISIC_0019127.JPG': 'Benign',
#  'archive\\ISIC_0019133.JPG': 'Benign',
#  'archive\\ISIC_0019135.JPG': 'Benign',
#  'archive\\ISIC_0019143.JPG': 'Benign',
#  'archive\\ISIC_0019148.JPG': 'Benign',
#  'archive\\ISIC_0019170.JPG': 'Benign',
#  'archive\\ISIC_0019173.JPG': 'Benign',
#  'archive\\ISIC_0019178.JPG': 'Benign',
#  'archive\\ISIC_0019199.JPG': 'Benign',
#  'archive\\ISIC_0019200.JPG': 'Benign',
#  'archive\\ISIC_0019204.JPG': 'Benign',
#  'archive\\ISIC_0019228.JPG': 'Benign',
#  'archive\\ISIC_0019260.JPG': 'Benign',
#  'archive\\ISIC_0019281.JPG': 'Benign',
#  'archive\\ISIC_0019303.JPG': 'Benign',
#  'archive\\ISIC_0019307.JPG': 'Benign',
#  'archive\\ISIC_0019312.JPG': 'Benign',
#  'archive\\ISIC_0019313.JPG': 'Benign',
#  'archive\\ISIC_0019315.JPG': 'Malignant',
#  'archive\\ISIC_0019320.JPG': 'Benign',
#  'archive\\ISIC_0019324.JPG': 'Benign',
#  'archive\\ISIC_0019326.JPG': 'Benign',
#  'archive\\ISIC_0019335.JPG': 'Benign',
#  'archive\\ISIC_0019354.JPG': 'Malignant',
#  'archive\\ISIC_0019364.JPG': 'Malignant',
#  'archive\\ISIC_0019366.JPG': 'Benign',
#  'archive\\ISIC_0019380.JPG': 'Benign',
#  'archive\\ISIC_0019385.JPG': 'Benign',
#  'archive\\ISIC_0019423.JPG': 'Benign',
#  'archive\\ISIC_0019424.JPG': 'Benign',
#  'archive\\ISIC_0019432.JPG': 'Benign',
#  'archive\\ISIC_0019453.JPG': 'Benign',
#  'archive\\ISIC_0019463.JPG': 'Malignant',
#  'archive\\ISIC_0019481.JPG': 'Benign',
#  'archive\\ISIC_0019512.JPG': 'Benign',
#  'archive\\ISIC_0019519.JPG': 'Benign',
#  'archive\\ISIC_0019528.JPG': 'Benign',
#  'archive\\ISIC_0019529.JPG': 'Benign',
#  'archive\\ISIC_0019531.JPG': 'Benign',
#  'archive\\ISIC_0019532.JPG': 'Benign',
#  'archive\\ISIC_0019540.JPG': 'Benign',
#  'archive\\ISIC_0019544.JPG': 'Benign',
#  'archive\\ISIC_0019545.JPG': 'Benign',
#  'archive\\ISIC_0019609.JPG': 'Benign',
#  'archive\\ISIC_0019627.JPG': 'Malignant',
#  'archive\\ISIC_0019628.JPG': 'Malignant',
#  'archive\\ISIC_0019638.JPG': 'Benign',
#  'archive\\ISIC_0019664.JPG': 'Benign',
#  'archive\\ISIC_0019669.JPG': 'Benign',
#  'archive\\ISIC_0019675.JPG': 'Benign',
#  'archive\\ISIC_0019678.JPG': 'Benign',
#  'archive\\ISIC_0019695.JPG': 'Malignant',
#  'archive\\ISIC_0019696.JPG': 'Benign',
#  'archive\\ISIC_0019703.JPG': 'Malignant',
#  'archive\\ISIC_0019733.JPG': 'Benign',
#  'archive\\ISIC_0019736.JPG': 'Benign',
#  'archive\\ISIC_0019747.JPG': 'Benign',
#  'archive\\ISIC_0019816.JPG': 'Benign',
#  'archive\\ISIC_0019870.JPG': 'Benign',
#  'archive\\ISIC_0019880.JPG': 'Benign',
#  'archive\\ISIC_0019902.JPG': 'Malignant',
#  'archive\\ISIC_0019903.JPG': 'Benign',
#  'archive\\ISIC_0019910.JPG': 'Benign',
#  'archive\\ISIC_0019911.JPG': 'Benign',
#  'archive\\ISIC_0019935.JPG': 'Benign',
#  'archive\\ISIC_0019964.JPG': 'Benign',
#  'archive\\ISIC_0019970.JPG': 'Benign',
#  'archive\\ISIC_0019981.JPG': 'Benign',
#  'archive\\ISIC_0019989.JPG': 'Benign',
#  'archive\\ISIC_0019992.JPG': 'Benign',
#  'archive\\ISIC_0020004.JPG': 'Benign',
#  'archive\\ISIC_0020005.JPG': 'Benign',
#  'archive\\ISIC_0020009.JPG': 'Benign',
#  'archive\\ISIC_0020081.JPG': 'Benign',
#  'archive\\ISIC_0020085.JPG': 'Benign',
#  'archive\\ISIC_0020124.JPG': 'Benign',
#  'archive\\ISIC_0020135.JPG': 'Malignant',
#  'archive\\ISIC_0020137.JPG': 'Benign',
#  'archive\\ISIC_0020150.JPG': 'Benign',
#  'archive\\ISIC_0020154.JPG': 'Benign',
#  'archive\\ISIC_0020166.JPG': 'Malignant',
#  'archive\\ISIC_0020185.JPG': 'Benign',
#  'archive\\ISIC_0020226.JPG': 'Benign',
#  'archive\\ISIC_0020235.JPG': 'Benign',
#  'archive\\ISIC_0020286.JPG': 'Benign',
#  'archive\\ISIC_0020300.JPG': 'Malignant',
#  'archive\\ISIC_0020307.JPG': 'Benign',
#  'archive\\ISIC_0020318.JPG': 'Malignant',
#  'archive\\ISIC_0020327.JPG': 'Benign',
#  'archive\\ISIC_0020334.JPG': 'Benign',
#  'archive\\ISIC_0020353.JPG': 'Benign',
#  'archive\\ISIC_0020359.JPG': 'Malignant',
#  'archive\\ISIC_0020360.JPG': 'Benign',
#  'archive\\ISIC_0020366.JPG': 'Benign',
#  'archive\\ISIC_0020372.JPG': 'Benign',
#  'archive\\ISIC_0020373.JPG': 'Benign',
#  'archive\\ISIC_0020409.JPG': 'Benign',
#  'archive\\ISIC_0020420.JPG': 'Malignant',
#  'archive\\ISIC_0020443.JPG': 'Benign',
#  'archive\\ISIC_0020454.JPG': 'Benign',
#  'archive\\ISIC_0020468.JPG': 'Benign',
#  'archive\\ISIC_0020479.JPG': 'Benign',
#  'archive\\ISIC_0020491.JPG': 'Benign',
#  'archive\\ISIC_0020500.JPG': 'Benign',
#  'archive\\ISIC_0020507.JPG': 'Benign',
#  'archive\\ISIC_0020508.JPG': 'Benign',
#  'archive\\ISIC_0020531.JPG': 'Benign',
#  'archive\\ISIC_0020540.JPG': 'Benign',
#  'archive\\ISIC_0020548.JPG': 'Malignant',
#  'archive\\ISIC_0020549.JPG': 'Benign',
#  'archive\\ISIC_0020550.JPG': 'Benign',
#  'archive\\ISIC_0020563.JPG': 'Malignant',
#  'archive\\ISIC_0020569.JPG': 'Malignant',
#  'archive\\ISIC_0020598.JPG': 'Benign',
#  'archive\\ISIC_0020601.JPG': 'Benign',
#  'archive\\ISIC_0020608.JPG': 'Benign',
#  'archive\\ISIC_0020613.JPG': 'Benign',
#  'archive\\ISIC_0020619.JPG': 'Benign',
#  'archive\\ISIC_0020620.JPG': 'Benign',
#  'archive\\ISIC_0020626.JPG': 'Benign',
#  'archive\\ISIC_0020632.JPG': 'Benign',
#  'archive\\ISIC_0020640.JPG': 'Malignant',
#  'archive\\ISIC_0020661.JPG': 'Benign',
#  'archive\\ISIC_0020663.JPG': 'Malignant',
#  'archive\\ISIC_0020667.JPG': 'Benign',
#  'archive\\ISIC_0020683.JPG': 'Benign',
#  'archive\\ISIC_0020714.JPG': 'Benign',
#  'archive\\ISIC_0020737.JPG': 'Benign',
#  'archive\\ISIC_0020743.JPG': 'Benign',
#  'archive\\ISIC_0020761.JPG': 'Benign',
#  'archive\\ISIC_0020764.JPG': 'Benign',
#  'archive\\ISIC_0020798.JPG': 'Benign',
#  'archive\\ISIC_0020803.JPG': 'Malignant',
#  'archive\\ISIC_0020840.JPG': 'Benign',
#  'archive\\ISIC_0020849.JPG': 'Benign',
#  'archive\\ISIC_0020860.JPG': 'Benign',
#  'archive\\ISIC_0020865.JPG': 'Benign',
#  'archive\\ISIC_0020879.JPG': 'Benign',
#  'archive\\ISIC_0020888.JPG': 'Benign',
#  'archive\\ISIC_0020895.JPG': 'Malignant',
#  'archive\\ISIC_0020896.JPG': 'Benign',
#  'archive\\ISIC_0020921.JPG': 'Benign',
#  'archive\\ISIC_0020930.JPG': 'Benign',
#  'archive\\ISIC_0020935.JPG': 'Benign',
#  'archive\\ISIC_0020951.JPG': 'Benign',
#  'archive\\ISIC_0020962.JPG': 'Benign',
#  'archive\\ISIC_0020972.JPG': 'Benign',
#  'archive\\ISIC_0020974.JPG': 'Benign',
#  'archive\\ISIC_0020987.JPG': 'Benign',
#  'archive\\ISIC_0021008.JPG': 'Benign',
#  'archive\\ISIC_0021010.JPG': 'Benign',
#  'archive\\ISIC_0021035.JPG': 'Benign',
#  'archive\\ISIC_0021036.JPG': 'Benign',
#  'archive\\ISIC_0021050.JPG': 'Benign',
#  'archive\\ISIC_0021051.JPG': 'Benign',
#  'archive\\ISIC_0021054.JPG': 'Benign',
#  'archive\\ISIC_0021070.JPG': 'Benign',
#  'archive\\ISIC_0021092.JPG': 'Benign',
#  'archive\\ISIC_0021103.JPG': 'Benign',
#  'archive\\ISIC_0021112.JPG': 'Benign',
#  'archive\\ISIC_0021114.JPG': 'Benign',
#  'archive\\ISIC_0021115.JPG': 'Benign',
#  'archive\\ISIC_0021121.JPG': 'Benign',
#  'archive\\ISIC_0021147.JPG': 'Benign',
#  'archive\\ISIC_0021156.JPG': 'Benign',
#  'archive\\ISIC_0021157.JPG': 'Benign',
#  'archive\\ISIC_0021160.JPG': 'Benign',
#  'archive\\ISIC_0021170.JPG': 'Malignant',
#  'archive\\ISIC_0021187.JPG': 'Benign',
#  'archive\\ISIC_0021195.JPG': 'Benign',
#  'archive\\ISIC_0021196.JPG': 'Benign',
#  'archive\\ISIC_0021201.JPG': 'Benign',
#  'archive\\ISIC_0021210.JPG': 'Benign',
#  'archive\\ISIC_0021225.JPG': 'Benign',
#  'archive\\ISIC_0021226.JPG': 'Benign',
#  'archive\\ISIC_0021227.JPG': 'Benign',
#  'archive\\ISIC_0021245.JPG': 'Benign',
#  'archive\\ISIC_0021260.JPG': 'Benign',
#  'archive\\ISIC_0021263.JPG': 'Benign',
#  'archive\\ISIC_0021270.JPG': 'Malignant',
#  'archive\\ISIC_0021278.JPG': 'Malignant',
#  'archive\\ISIC_0021313.JPG': 'Benign',
#  'archive\\ISIC_0021319.JPG': 'Benign',
#  'archive\\ISIC_0021333.JPG': 'Benign',
#  'archive\\ISIC_0021342.JPG': 'Benign',
#  'archive\\ISIC_0021347.JPG': 'Benign',
#  'archive\\ISIC_0021354.JPG': 'Benign',
#  'archive\\ISIC_0021374.JPG': 'Benign',
#  'archive\\ISIC_0021379.JPG': 'Benign',
#  'archive\\ISIC_0021380.JPG': 'Benign',
#  'archive\\ISIC_0021406.JPG': 'Benign',
#  'archive\\ISIC_0021407.JPG': 'Benign',
#  'archive\\ISIC_0021440.JPG': 'Malignant',
#  'archive\\ISIC_0021447.JPG': 'Benign',
#  'archive\\ISIC_0021451.JPG': 'Malignant',
#  'archive\\ISIC_0021452.JPG': 'Benign',
#  'archive\\ISIC_0021453.JPG': 'Benign',
#  'archive\\ISIC_0021480.JPG': 'Benign',
#  'archive\\ISIC_0021494.JPG': 'Benign',
#  'archive\\ISIC_0021506.JPG': 'Malignant',
#  'archive\\ISIC_0021550.JPG': 'Benign',
#  'archive\\ISIC_0021551.JPG': 'Benign',
#  'archive\\ISIC_0021554.JPG': 'Benign',
#  'archive\\ISIC_0021558.JPG': 'Malignant',
#  'archive\\ISIC_0021559.JPG': 'Malignant',
#  'archive\\ISIC_0021570.JPG': 'Benign',
#  'archive\\ISIC_0021573.JPG': 'Benign',
#  'archive\\ISIC_0021579.JPG': 'Benign',
#  'archive\\ISIC_0021583.JPG': 'Malignant',
#  'archive\\ISIC_0021584.JPG': 'Benign',
#  'archive\\ISIC_0021591.JPG': 'Benign',
#  'archive\\ISIC_0021593.JPG': 'Benign',
#  'archive\\ISIC_0021596.JPG': 'Malignant',
#  'archive\\ISIC_0021601.JPG': 'Benign',
#  'archive\\ISIC_0021604.JPG': 'Benign',
#  'archive\\ISIC_0021615.JPG': 'Benign',
#  'archive\\ISIC_0021616.JPG': 'Benign',
#  'archive\\ISIC_0021618.JPG': 'Benign',
#  'archive\\ISIC_0021622.JPG': 'Benign',
#  'archive\\ISIC_0021625.JPG': 'Benign',
#  'archive\\ISIC_0021647.JPG': 'Benign',
#  'archive\\ISIC_0021648.JPG': 'Benign',
#  'archive\\ISIC_0021659.JPG': 'Benign',
#  'archive\\ISIC_0021688.JPG': 'Benign',
#  'archive\\ISIC_0021701.JPG': 'Malignant',
#  'archive\\ISIC_0021711.JPG': 'Malignant',
#  'archive\\ISIC_0021734.JPG': 'Benign',
#  'archive\\ISIC_0021738.JPG': 'Malignant',
#  'archive\\ISIC_0021751.JPG': 'Malignant',
#  'archive\\ISIC_0021753.JPG': 'Benign',
#  'archive\\ISIC_0021765.JPG': 'Benign',
#  'archive\\ISIC_0021770.JPG': 'Benign',
#  'archive\\ISIC_0021777.JPG': 'Benign',
#  'archive\\ISIC_0021780.JPG': 'Benign',
#  'archive\\ISIC_0021786.JPG': 'Benign',
#  'archive\\ISIC_0021790.JPG': 'Benign',
#  'archive\\ISIC_0021791.JPG': 'Benign',
#  'archive\\ISIC_0021796.JPG': 'Benign',
#  'archive\\ISIC_0021798.JPG': 'Malignant',
#  'archive\\ISIC_0021800.JPG': 'Malignant',
#  'archive\\ISIC_0021826.JPG': 'Malignant',
#  'archive\\ISIC_0021832.JPG': 'Malignant',
#  'archive\\ISIC_0021833.JPG': 'Benign',
#  'archive\\ISIC_0021837.JPG': 'Malignant',
#  'archive\\ISIC_0021845.JPG': 'Benign',
#  'archive\\ISIC_0021873.JPG': 'Malignant',
#  'archive\\ISIC_0021874.JPG': 'Malignant',
#  'archive\\ISIC_0021893.JPG': 'Benign',
#  'archive\\ISIC_0021902.JPG': 'Malignant',
#  'archive\\ISIC_0021910.JPG': 'Malignant',
#  'archive\\ISIC_0021921.JPG': 'Malignant',
#  'archive\\ISIC_0021930.JPG': 'Benign',
#  'archive\\ISIC_0021932.JPG': 'Benign',
#  'archive\\ISIC_0021936.JPG': 'Malignant',
#  'archive\\ISIC_0021940.JPG': 'Benign',
#  'archive\\ISIC_0021952.JPG': 'Malignant',
#  'archive\\ISIC_0021953.JPG': 'Benign',
#  'archive\\ISIC_0021955.JPG': 'Benign',
#  'archive\\ISIC_0021956.JPG': 'Malignant',
#  'archive\\ISIC_0021959.JPG': 'Benign',
#  'archive\\ISIC_0021973.JPG': 'Benign',
#  'archive\\ISIC_0021987.JPG': 'Benign',
#  'archive\\ISIC_0021988.JPG': 'Benign',
#  'archive\\ISIC_0021999.JPG': 'Malignant',
#  'archive\\ISIC_0022006.JPG': 'Benign',
#  'archive\\ISIC_0022007.JPG': 'Benign',
#  'archive\\ISIC_0022009.JPG': 'Malignant',
#  'archive\\ISIC_0022015.JPG': 'Benign',
#  'archive\\ISIC_0022025.JPG': 'Benign',
#  'archive\\ISIC_0022028.JPG': 'Benign',
#  'archive\\ISIC_0022041.JPG': 'Benign',
#  'archive\\ISIC_0022043.JPG': 'Benign',
#  'archive\\ISIC_0022044.JPG': 'Malignant',
#  'archive\\ISIC_0022073.JPG': 'Benign',
#  'archive\\ISIC_0022108.JPG': 'Malignant',
#  'archive\\ISIC_0022149.JPG': 'Malignant',
#  'archive\\ISIC_0022160.JPG': 'Benign',
#  'archive\\ISIC_0022186.JPG': 'Benign',
#  'archive\\ISIC_0022191.JPG': 'Benign',
#  'archive\\ISIC_0022203.JPG': 'Benign',
#  'archive\\ISIC_0022208.JPG': 'Benign',
#  'archive\\ISIC_0022210.JPG': 'Benign',
#  'archive\\ISIC_0022213.JPG': 'Benign',
#  'archive\\ISIC_0022215.JPG': 'Benign',
#  'archive\\ISIC_0022217.JPG': 'Benign',
#  'archive\\ISIC_0022219.JPG': 'Benign',
#  'archive\\ISIC_0022220.JPG': 'Benign',
#  'archive\\ISIC_0022231.JPG': 'Benign',
#  'archive\\ISIC_0022245.JPG': 'Benign',
#  'archive\\ISIC_0022247.JPG': 'Malignant',
#  'archive\\ISIC_0022254.JPG': 'Benign',
#  'archive\\ISIC_0022257.JPG': 'Benign',
#  'archive\\ISIC_0022261.JPG': 'Benign',
#  'archive\\ISIC_0022274.JPG': 'Benign',
#  'archive\\ISIC_0022288.JPG': 'Benign',
#  'archive\\ISIC_0022289.JPG': 'Benign',
#  'archive\\ISIC_0022308.JPG': 'Malignant',
#  'archive\\ISIC_0022313.JPG': 'Benign',
#  'archive\\ISIC_0022317.JPG': 'Benign',
#  'archive\\ISIC_0022329.JPG': 'Benign',
#  'archive\\ISIC_0022330.JPG': 'Benign',
#  'archive\\ISIC_0022335.JPG': 'Benign',
#  'archive\\ISIC_0022342.JPG': 'Malignant',
#  'archive\\ISIC_0022367.JPG': 'Benign',
#  'archive\\ISIC_0022381.JPG': 'Benign',
#  'archive\\ISIC_0022395.JPG': 'Malignant',
#  'archive\\ISIC_0022399.JPG': 'Benign',
#  'archive\\ISIC_0022436.JPG': 'Malignant',
#  'archive\\ISIC_0022444.JPG': 'Benign',
#  'archive\\ISIC_0022457.JPG': 'Malignant',
#  'archive\\ISIC_0022540.JPG': 'Malignant',
#  'archive\\ISIC_0022546.JPG': 'Benign',
#  'archive\\ISIC_0022550.JPG': 'Malignant',
#  'archive\\ISIC_0022551.JPG': 'Benign',
#  'archive\\ISIC_0022552.JPG': 'Malignant',
#  'archive\\ISIC_0022558.JPG': 'Malignant',
#  'archive\\ISIC_0022570.JPG': 'Benign',
#  'archive\\ISIC_0022571.JPG': 'Benign',
#  'archive\\ISIC_0022572.JPG': 'Benign',
#  'archive\\ISIC_0022574.JPG': 'Benign',
#  'archive\\ISIC_0022580.JPG': 'Benign',
#  'archive\\ISIC_0022588.JPG': 'Benign',
#  'archive\\ISIC_0022591.JPG': 'Benign',
#  'archive\\ISIC_0022623.JPG': 'Benign',
#  'archive\\ISIC_0022649.JPG': 'Benign',
#  'archive\\ISIC_0022650.JPG': 'Benign',
#  'archive\\ISIC_0022659.JPG': 'Benign',
#  'archive\\ISIC_0022662.JPG': 'Benign',
#  'archive\\ISIC_0022663.JPG': 'Malignant',
#  'archive\\ISIC_0022678.JPG': 'Malignant',
#  'archive\\ISIC_0022730.JPG': 'Benign',
#  'archive\\ISIC_0022732.JPG': 'Benign',
#  'archive\\ISIC_0022733.JPG': 'Benign',
#  'archive\\ISIC_0022735.JPG': 'Benign',
#  'archive\\ISIC_0022736.JPG': 'Benign',
#  'archive\\ISIC_0022741.JPG': 'Benign',
#  'archive\\ISIC_0022742.JPG': 'Benign',
#  'archive\\ISIC_0022776.JPG': 'Benign',
#  'archive\\ISIC_0022781.JPG': 'Benign',
#  'archive\\ISIC_0022787.JPG': 'Benign',
#  'archive\\ISIC_0022819.JPG': 'Malignant',
#  'archive\\ISIC_0022820.JPG': 'Malignant',
#  'archive\\ISIC_0022828.JPG': 'Benign',
#  'archive\\ISIC_0022844.JPG': 'Benign',
#  'archive\\ISIC_0022845.JPG': 'Benign',
#  'archive\\ISIC_0022849.JPG': 'Benign',
#  'archive\\ISIC_0022851.JPG': 'Benign',
#  'archive\\ISIC_0022856.JPG': 'Malignant',
#  'archive\\ISIC_0022857.JPG': 'Malignant',
#  'archive\\ISIC_0022917.JPG': 'Benign',
#  'archive\\ISIC_0022928.JPG': 'Benign',
#  'archive\\ISIC_0022950.JPG': 'Malignant',
#  'archive\\ISIC_0023013.JPG': 'Benign',
#  'archive\\ISIC_0023029.JPG': 'Benign',
#  'archive\\ISIC_0023056.JPG': 'Malignant',
#  'archive\\ISIC_0023090.JPG': 'Benign',
#  'archive\\ISIC_0023101.JPG': 'Benign',
#  'archive\\ISIC_0023118.JPG': 'Benign',
#  'archive\\ISIC_0023121.JPG': 'Benign',
#  'archive\\ISIC_0023128.JPG': 'Malignant',
#  'archive\\ISIC_0023135.JPG': 'Benign',
#  'archive\\ISIC_0023145.JPG': 'Benign',
#  'archive\\ISIC_0023156.JPG': 'Benign',
#  'archive\\ISIC_0023158.JPG': 'Benign',
#  'archive\\ISIC_0023159.JPG': 'Benign',
#  'archive\\ISIC_0023164.JPG': 'Malignant',
#  'archive\\ISIC_0023199.JPG': 'Benign',
#  'archive\\ISIC_0023201.JPG': 'Benign',
#  'archive\\ISIC_0023202.JPG': 'Benign',
#  'archive\\ISIC_0023203.JPG': 'Benign',
#  'archive\\ISIC_0023205.JPG': 'Benign',
#  'archive\\ISIC_0023207.JPG': 'Malignant',
#  'archive\\ISIC_0023211.JPG': 'Benign',
#  'archive\\ISIC_0023221.JPG': 'Benign',
#  'archive\\ISIC_0023232.JPG': 'Benign',
#  'archive\\ISIC_0023235.JPG': 'Malignant',
#  'archive\\ISIC_0023257.JPG': 'Benign',
#  'archive\\ISIC_0023258.JPG': 'Benign',
#  'archive\\ISIC_0023261.JPG': 'Benign',
#  'archive\\ISIC_0023264.JPG': 'Benign',
#  'archive\\ISIC_0023269.JPG': 'Benign',
#  'archive\\ISIC_0023274.JPG': 'Benign',
#  'archive\\ISIC_0023275.JPG': 'Benign',
#  'archive\\ISIC_0023283.JPG': 'Benign',
#  'archive\\ISIC_0023298.JPG': 'Malignant',
#  'archive\\ISIC_0023300.JPG': 'Malignant',
#  'archive\\ISIC_0023301.JPG': 'Malignant',
#  'archive\\ISIC_0023306.JPG': 'Benign',
#  'archive\\ISIC_0023309.JPG': 'Benign',
#  'archive\\ISIC_0023316.JPG': 'Benign',
#  'archive\\ISIC_0023321.JPG': 'Malignant',
#  'archive\\ISIC_0023322.JPG': 'Benign',
#  'archive\\ISIC_0023323.JPG': 'Benign',
#  'archive\\ISIC_0023343.JPG': 'Benign',
#  'archive\\ISIC_0023346.JPG': 'Benign',
#  'archive\\ISIC_0023356.JPG': 'Benign',
#  'archive\\ISIC_0023358.JPG': 'Benign',
#  'archive\\ISIC_0023364.JPG': 'Benign',
#  'archive\\ISIC_0023366.JPG': 'Benign',
#  'archive\\ISIC_0023379.JPG': 'Malignant',
#  'archive\\ISIC_0023380.JPG': 'Malignant',
#  'archive\\ISIC_0023381.JPG': 'Malignant',
#  'archive\\ISIC_0023393.JPG': 'Benign',
#  'archive\\ISIC_0023396.JPG': 'Malignant',
#  'archive\\ISIC_0023431.JPG': 'Malignant',
#  'archive\\ISIC_0023449.JPG': 'Benign',
#  'archive\\ISIC_0023468.JPG': 'Benign',
#  'archive\\ISIC_0023470.JPG': 'Benign',
#  'archive\\ISIC_0023472.JPG': 'Benign',
#  'archive\\ISIC_0023474.JPG': 'Benign',
#  'archive\\ISIC_0023481.JPG': 'Benign',
#  'archive\\ISIC_0023482.JPG': 'Benign',
#  'archive\\ISIC_0023483.JPG': 'Malignant',
#  'archive\\ISIC_0023498.JPG': 'Benign',
#  'archive\\ISIC_0023506.JPG': 'Malignant',
#  'archive\\ISIC_0023522.JPG': 'Benign',
#  'archive\\ISIC_0023543.JPG': 'Malignant',
#  'archive\\ISIC_0023553.JPG': 'Benign',
#  'archive\\ISIC_0023557.JPG': 'Malignant',
#  'archive\\ISIC_0023575.JPG': 'Benign',
#  'archive\\ISIC_0023620.JPG': 'Malignant',
#  'archive\\ISIC_0023625.JPG': 'Benign',
#  'archive\\ISIC_0023646.JPG': 'Malignant',
#  'archive\\ISIC_0023658.JPG': 'Benign',
#  'archive\\ISIC_0023676.JPG': 'Benign',
#  'archive\\ISIC_0023694.JPG': 'Benign',
#  'archive\\ISIC_0023696.JPG': 'Malignant',
#  'archive\\ISIC_0023715.JPG': 'Benign',
#  'archive\\ISIC_0023721.JPG': 'Benign',
#  'archive\\ISIC_0023747.JPG': 'Benign',
#  'archive\\ISIC_0023752.JPG': 'Benign',
#  'archive\\ISIC_0023761.JPG': 'Benign',
#  'archive\\ISIC_0023762.JPG': 'Malignant',
#  'archive\\ISIC_0023765.JPG': 'Malignant',
#  'archive\\ISIC_0023772.JPG': 'Benign',
#  'archive\\ISIC_0023779.JPG': 'Benign',
#  'archive\\ISIC_0023783.JPG': 'Benign',
#  'archive\\ISIC_0023784.JPG': 'Benign',
#  'archive\\ISIC_0023793.JPG': 'Benign',
#  'archive\\ISIC_0023804.JPG': 'Malignant',
#  'archive\\ISIC_0023812.JPG': 'Benign',
#  'archive\\ISIC_0023813.JPG': 'Benign',
#  'archive\\ISIC_0023821.JPG': 'Benign',
#  'archive\\ISIC_0023832.JPG': 'Benign',
#  'archive\\ISIC_0023836.JPG': 'Benign',
#  'archive\\ISIC_0023854.JPG': 'Benign',
#  'archive\\ISIC_0023881.JPG': 'Benign',
#  'archive\\ISIC_0023885.JPG': 'Benign',
#  'archive\\ISIC_0023901.JPG': 'Benign',
#  'archive\\ISIC_0023911.JPG': 'Benign',
#  'archive\\ISIC_0023912.JPG': 'Benign',
#  'archive\\ISIC_0023916.JPG': 'Malignant',
#  'archive\\ISIC_0023920.JPG': 'Benign',
#  'archive\\ISIC_0023933.JPG': 'Benign',
#  'archive\\ISIC_0023940.JPG': 'Benign',
#  'archive\\ISIC_0023948.JPG': 'Benign',
#  'archive\\ISIC_0024005.JPG': 'Benign',
#  'archive\\ISIC_0024032.JPG': 'Malignant',
#  'archive\\ISIC_0024043.JPG': 'Malignant',
#  'archive\\ISIC_0024054.JPG': 'Benign',
#  'archive\\ISIC_0024095.JPG': 'Benign',
#  'archive\\ISIC_0024100.JPG': 'Benign',
#  'archive\\ISIC_0024104.JPG': 'Benign',
#  'archive\\ISIC_0024105.JPG': 'Benign',
#  'archive\\ISIC_0024106.JPG': 'Benign',
#  'archive\\ISIC_0024130.JPG': 'Benign',
#  'archive\\ISIC_0024137.JPG': 'Benign',
#  'archive\\ISIC_0024139.JPG': 'Benign',
#  'archive\\ISIC_0024156.JPG': 'Malignant',
#  'archive\\ISIC_0024157.JPG': 'Malignant',
#  'archive\\ISIC_0024188.JPG': 'Benign',
#  'archive\\ISIC_0024191.JPG': 'Benign',
#  'archive\\ISIC_0036066.JPG': 'Malignant',
#  'archive\\ISIC_0036067.JPG': 'Benign',
#  'archive\\ISIC_0036070.JPG': 'Benign',
#  'archive\\ISIC_0036075.JPG': 'Malignant',
#  'archive\\ISIC_0036076.JPG': 'Benign',
#  'archive\\ISIC_0036078.JPG': 'Benign',
#  'archive\\ISIC_0036079.JPG': 'Benign',
#  'archive\\ISIC_0036080.JPG': 'Benign',
#  'archive\\ISIC_0036081.JPG': 'Benign',
#  'archive\\ISIC_0036083.JPG': 'Benign',
#  'archive\\ISIC_0036086.JPG': 'Malignant',
#  'archive\\ISIC_0036087.JPG': 'Benign',
#  'archive\\ISIC_0036088.JPG': 'Benign',
#  'archive\\ISIC_0036089.JPG': 'Benign',
#  'archive\\ISIC_0036090.JPG': 'Malignant',
#  'archive\\ISIC_0036091.JPG': 'Malignant',
#  'archive\\ISIC_0036092.JPG': 'Benign',
#  'archive\\ISIC_0036093.JPG': 'Benign',
#  'archive\\ISIC_0036094.JPG': 'Benign',
#  'archive\\ISIC_0036095.JPG': 'Benign',
#  'archive\\ISIC_0036096.JPG': 'Malignant',
#  'archive\\ISIC_0036097.JPG': 'Benign',
#  'archive\\ISIC_0036099.JPG': 'Benign',
#  'archive\\ISIC_0036100.JPG': 'Benign',
#  'archive\\ISIC_0036102.JPG': 'Benign',
#  'archive\\ISIC_0036103.JPG': 'Malignant',
#  'archive\\ISIC_0036104.JPG': 'Benign',
#  'archive\\ISIC_0036105.JPG': 'Malignant',
#  'archive\\ISIC_0036106.JPG': 'Benign',
#  'archive\\ISIC_0036107.JPG': 'Benign',
#  'archive\\ISIC_0036108.JPG': 'Malignant',
#  'archive\\ISIC_0036109.JPG': 'Benign',
#  'archive\\ISIC_0036110.JPG': 'Malignant',
#  'archive\\ISIC_0036111.JPG': 'Malignant',
#  'archive\\ISIC_0036112.JPG': 'Benign',
#  'archive\\ISIC_0036113.JPG': 'Benign',
#  'archive\\ISIC_0036114.JPG': 'Benign',
#  'archive\\ISIC_0036115.JPG': 'Benign',
#  'archive\\ISIC_0036116.JPG': 'Benign',
#  'archive\\ISIC_0036117.JPG': 'Benign',
#  'archive\\ISIC_0036118.JPG': 'Benign',
#  'archive\\ISIC_0036119.JPG': 'Benign',
#  'archive\\ISIC_0036120.JPG': 'Benign',
#  'archive\\ISIC_0036122.JPG': 'Benign',
#  'archive\\ISIC_0036123.JPG': 'Malignant',
#  'archive\\ISIC_0036124.JPG': 'Benign',
#  'archive\\ISIC_0036125.JPG': 'Benign',
#  'archive\\ISIC_0036126.JPG': 'Benign',
#  'archive\\ISIC_0036127.JPG': 'Benign',
#  'archive\\ISIC_0036128.JPG': 'Malignant',
#  'archive\\ISIC_0036129.JPG': 'Benign',
#  'archive\\ISIC_0036130.JPG': 'Benign',
#  'archive\\ISIC_0036131.JPG': 'Benign',
#  'archive\\ISIC_0036132.JPG': 'Benign',
#  'archive\\ISIC_0036133.JPG': 'Benign',
#  'archive\\ISIC_0036134.JPG': 'Benign',
#  'archive\\ISIC_0036135.JPG': 'Benign',
#  'archive\\ISIC_0036136.JPG': 'Benign',
#  'archive\\ISIC_0036137.JPG': 'Benign',
#  'archive\\ISIC_0036138.JPG': 'Malignant',
#  'archive\\ISIC_0036139.JPG': 'Malignant',
#  'archive\\ISIC_0036140.JPG': 'Benign',
#  'archive\\ISIC_0036141.JPG': 'Benign',
#  'archive\\ISIC_0036142.JPG': 'Benign',
#  'archive\\ISIC_0036143.JPG': 'Malignant',
#  'archive\\ISIC_0036144.JPG': 'Benign',
#  'archive\\ISIC_0036145.JPG': 'Benign',
#  'archive\\ISIC_0036146.JPG': 'Benign',
#  'archive\\ISIC_0036148.JPG': 'Malignant',
#  'archive\\ISIC_0036149.JPG': 'Benign',
#  'archive\\ISIC_0036150.JPG': 'Benign',
#  'archive\\ISIC_0036151.JPG': 'Malignant',
#  'archive\\ISIC_0036152.JPG': 'Benign',
#  'archive\\ISIC_0036153.JPG': 'Benign',
#  'archive\\ISIC_0036154.JPG': 'Benign',
#  'archive\\ISIC_0036155.JPG': 'Benign',
#  'archive\\ISIC_0036156.JPG': 'Malignant',
#  'archive\\ISIC_0036157.JPG': 'Malignant',
#  'archive\\ISIC_0036158.JPG': 'Benign',
#  'archive\\ISIC_0036159.JPG': 'Benign',
#  'archive\\ISIC_0036160.JPG': 'Benign',
#  'archive\\ISIC_0036162.JPG': 'Benign',
#  'archive\\ISIC_0036163.JPG': 'Benign',
#  'archive\\ISIC_0036164.JPG': 'Benign',
#  'archive\\ISIC_0036165.JPG': 'Malignant',
#  'archive\\ISIC_0036166.JPG': 'Benign',
#  'archive\\ISIC_0036167.JPG': 'Benign',
#  'archive\\ISIC_0036168.JPG': 'Benign',
#  'archive\\ISIC_0036169.JPG': 'Benign',
#  'archive\\ISIC_0036170.JPG': 'Benign',
#  'archive\\ISIC_0036171.JPG': 'Benign',
#  'archive\\ISIC_0036172.JPG': 'Malignant',
#  'archive\\ISIC_0036173.JPG': 'Benign',
#  'archive\\ISIC_0036175.JPG': 'Benign',
#  'archive\\ISIC_0036176.JPG': 'Benign',
#  'archive\\ISIC_0036177.JPG': 'Malignant',
#  'archive\\ISIC_0036178.JPG': 'Benign',
#  'archive\\ISIC_0036179.JPG': 'Benign',
#  'archive\\ISIC_0036180.JPG': 'Benign',
#  'archive\\ISIC_0036181.JPG': 'Benign',
#  'archive\\ISIC_0036182.JPG': 'Benign',
#  'archive\\ISIC_0036183.JPG': 'Benign',
#  'archive\\ISIC_0036184.JPG': 'Malignant',
#  'archive\\ISIC_0036185.JPG': 'Malignant',
#  'archive\\ISIC_0036186.JPG': 'Benign',
#  'archive\\ISIC_0036187.JPG': 'Benign',
#  'archive\\ISIC_0036188.JPG': 'Benign',
#  'archive\\ISIC_0036189.JPG': 'Benign',
#  'archive\\ISIC_0036190.JPG': 'Benign',
#  'archive\\ISIC_0036191.JPG': 'Benign',
#  'archive\\ISIC_0036192.JPG': 'Benign',
#  'archive\\ISIC_0036193.JPG': 'Benign',
#  'archive\\ISIC_0036194.JPG': 'Benign',
#  'archive\\ISIC_0036195.JPG': 'Benign',
#  'archive\\ISIC_0036196.JPG': 'Benign',
#  'archive\\ISIC_0036197.JPG': 'Malignant',
#  'archive\\ISIC_0036198.JPG': 'Benign',
#  'archive\\ISIC_0036199.JPG': 'Benign',
#  'archive\\ISIC_0036200.JPG': 'Benign',
#  'archive\\ISIC_0036201.JPG': 'Benign',
#  'archive\\ISIC_0036202.JPG': 'Benign',
#  'archive\\ISIC_0036203.JPG': 'Malignant',
#  'archive\\ISIC_0036204.JPG': 'Benign',
#  'archive\\ISIC_0036205.JPG': 'Benign',
#  'archive\\ISIC_0036207.JPG': 'Benign',
#  'archive\\ISIC_0036208.JPG': 'Benign',
#  'archive\\ISIC_0036209.JPG': 'Benign',
#  'archive\\ISIC_0036211.JPG': 'Malignant',
#  'archive\\ISIC_0036212.JPG': 'Benign',
#  'archive\\ISIC_0036213.JPG': 'Benign',
#  'archive\\ISIC_0036214.JPG': 'Benign',
#  'archive\\ISIC_0036215.JPG': 'Benign',
#  'archive\\ISIC_0036216.JPG': 'Benign',
#  'archive\\ISIC_0036217.JPG': 'Benign',
#  'archive\\ISIC_0036218.JPG': 'Benign',
#  'archive\\ISIC_0036219.JPG': 'Benign',
#  'archive\\ISIC_0036220.JPG': 'Benign',
#  'archive\\ISIC_0036221.JPG': 'Benign',
#  'archive\\ISIC_0036222.JPG': 'Benign',
#  'archive\\ISIC_0036223.JPG': 'Malignant',
#  'archive\\ISIC_0036224.JPG': 'Benign',
#  'archive\\ISIC_0036225.JPG': 'Malignant',
#  'archive\\ISIC_0036226.JPG': 'Benign',
#  'archive\\ISIC_0036227.JPG': 'Benign',
#  'archive\\ISIC_0036228.JPG': 'Benign',
#  'archive\\ISIC_0036229.JPG': 'Benign',
#  'archive\\ISIC_0036230.JPG': 'Malignant',
#  'archive\\ISIC_0036231.JPG': 'Benign',
#  'archive\\ISIC_0036232.JPG': 'Malignant',
#  'archive\\ISIC_0036233.JPG': 'Benign',
#  'archive\\ISIC_0036234.JPG': 'Benign',
#  'archive\\ISIC_0036235.JPG': 'Benign',
#  'archive\\ISIC_0036238.JPG': 'Benign',
#  'archive\\ISIC_0036239.JPG': 'Benign',
#  'archive\\ISIC_0036241.JPG': 'Benign',
#  'archive\\ISIC_0036242.JPG': 'Benign',
#  'archive\\ISIC_0036243.JPG': 'Benign',
#  'archive\\ISIC_0036248.JPG': 'Malignant',
#  'archive\\ISIC_0036249.JPG': 'Benign',
#  'archive\\ISIC_0036250.JPG': 'Benign',
#  'archive\\ISIC_0036251.JPG': 'Malignant',
#  'archive\\ISIC_0036252.JPG': 'Benign',
#  'archive\\ISIC_0036253.JPG': 'Malignant',
#  'archive\\ISIC_0036254.JPG': 'Benign',
#  'archive\\ISIC_0036255.JPG': 'Benign',
#  'archive\\ISIC_0036256.JPG': 'Benign',
#  'archive\\ISIC_0036257.JPG': 'Malignant',
#  'archive\\ISIC_0036258.JPG': 'Benign',
#  'archive\\ISIC_0036259.JPG': 'Malignant',
#  'archive\\ISIC_0036260.JPG': 'Benign',
#  'archive\\ISIC_0036261.JPG': 'Benign',
#  'archive\\ISIC_0036262.JPG': 'Benign',
#  'archive\\ISIC_0036263.JPG': 'Benign',
#  'archive\\ISIC_0036264.JPG': 'Malignant',
#  'archive\\ISIC_0036265.JPG': 'Malignant',
#  'archive\\ISIC_0036266.JPG': 'Benign',
#  'archive\\ISIC_0036267.JPG': 'Benign',
#  'archive\\ISIC_0036268.JPG': 'Benign',
#  'archive\\ISIC_0036269.JPG': 'Malignant',
#  'archive\\ISIC_0036270.JPG': 'Malignant',
#  'archive\\ISIC_0036273.JPG': 'Malignant',
#  'archive\\ISIC_0036274.JPG': 'Malignant',
#  'archive\\ISIC_0036275.JPG': 'Malignant',
#  'archive\\ISIC_0036276.JPG': 'Malignant',
#  'archive\\ISIC_0036277.JPG': 'Benign',
#  'archive\\ISIC_0036278.JPG': 'Benign',
#  'archive\\ISIC_0036279.JPG': 'Benign',
#  'archive\\ISIC_0036280.JPG': 'Benign',
#  'archive\\ISIC_0036282.JPG': 'Malignant',
#  'archive\\ISIC_0036284.JPG': 'Benign',
#  'archive\\ISIC_0036285.JPG': 'Benign',
#  'archive\\ISIC_0036286.JPG': 'Malignant',
#  'archive\\ISIC_0036287.JPG': 'Benign',
#  'archive\\ISIC_0036288.JPG': 'Benign',
#  'archive\\ISIC_0036289.JPG': 'Benign',
#  'archive\\ISIC_0036290.JPG': 'Benign',
#  'archive\\ISIC_0036292.JPG': 'Benign',
#  'archive\\ISIC_0036293.JPG': 'Benign',
#  'archive\\ISIC_0036294.JPG': 'Malignant',
#  'archive\\ISIC_0036295.JPG': 'Benign',
#  'archive\\ISIC_0036296.JPG': 'Benign',
#  'archive\\ISIC_0036297.JPG': 'Malignant',
#  'archive\\ISIC_0036298.JPG': 'Benign',
#  'archive\\ISIC_0036300.JPG': 'Benign',
#  'archive\\ISIC_0036301.JPG': 'Benign',
#  'archive\\ISIC_0036302.JPG': 'Benign',
#  'archive\\ISIC_0036303.JPG': 'Benign',
#  'archive\\ISIC_0036304.JPG': 'Benign',
#  'archive\\ISIC_0036305.JPG': 'Benign',
#  'archive\\ISIC_0036307.JPG': 'Benign',
#  'archive\\ISIC_0036308.JPG': 'Benign',
#  'archive\\ISIC_0036309.JPG': 'Benign',
#  'archive\\ISIC_0036310.JPG': 'Benign',
#  'archive\\ISIC_0036311.JPG': 'Benign',
#  'archive\\ISIC_0036312.JPG': 'Benign',
#  'archive\\ISIC_0036313.JPG': 'Benign',
#  'archive\\ISIC_0036315.JPG': 'Benign',
#  'archive\\ISIC_0036317.JPG': 'Benign',
#  'archive\\ISIC_0036318.JPG': 'Benign',
#  'archive\\ISIC_0036319.JPG': 'Benign',
#  'archive\\ISIC_0036322.JPG': 'Benign',
#  'archive\\ISIC_0036323.JPG': 'Benign',
#  'archive\\ISIC_0036325.JPG': 'Benign',
#  'archive\\ISIC_0036326.JPG': 'Benign',
#  'archive\\ISIC_0036327.JPG': 'Benign',
#  'archive\\ISIC_0036329.JPG': 'Malignant',
#  'archive\\ISIC_0036331.JPG': 'Benign',
#  'archive\\ISIC_0036332.JPG': 'Benign',
#  'archive\\ISIC_0036335.JPG': 'Benign',
#  'archive\\ISIC_0036336.JPG': 'Malignant',
#  'archive\\ISIC_0036337.JPG': 'Benign',
#  'archive\\ISIC_0036338.JPG': 'Benign',
#  'archive\\ISIC_0036340.JPG': 'Benign',
#  'archive\\ISIC_0036341.JPG': 'Benign',
#  'archive\\ISIC_0036342.JPG': 'Benign',
#  'archive\\ISIC_0036343.JPG': 'Malignant',
#  'archive\\ISIC_0036344.JPG': 'Malignant',
#  'archive\\ISIC_0036345.JPG': 'Benign',
#  'archive\\ISIC_0036346.JPG': 'Benign',
#  'archive\\ISIC_0036347.JPG': 'Benign'}
